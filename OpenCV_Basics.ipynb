# %% [raw]
# OpenCV Python Tutorial
# Difficulty Level : Hard
# Last Updated : 28 Mar, 2021
# OpenCV is a huge open-source library for computer vision, machine learning, and image processing. OpenCV supports a wide variety of programming languages like Python, C++, Java, etc. It can process images and videos to identify objects, faces, or even the handwriting of a human. When it is integrated with various libraries, such as Numpy which is a highly optimized library for numerical operations, then the number of weapons increases in your Arsenal i.e whatever operations one can do in Numpy can be combined with OpenCV.

# %%
#pip install opencv-python

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
''' To read the images cv2.imread() method is used. 
This method loads an image from the specified file'''

image=cv2.imread('road.jpg',cv2.IMREAD_COLOR)


cv2.namedWindow('Road Image', cv2.WINDOW_NORMAL)


'''cv2.imshow() method is used to display an image in a window.
The window automatically fits to the image size.'''
cv2.imshow('Road Image',image)  

'''
#waits for user to press any key 
#(this is necessary to avoid Python kernel form crashing)'''
cv2.waitKey(0)

'''#closing all open windows '''
cv2.destroyAllWindows()

H, W = image.shape[ : 2]
print('Height: {}, width: {}'.format(H,W))
# Out:
# Height: 1603, width: 2400

# %%
#Extracting RGB values of pixel
R, G, B = image[100,100]
print(R,G,B)
# Out:
# 165 172 211

# %%
image[100,100,1]
# Out:
# 172

# %%
image[100,100,2]
# Out:
# 211

# %% [markdown]
# ### Extracting ROI

# %%
roi=image[950:1500, 50:550]
cv2.namedWindow('Region of Interest', cv2.WINDOW_GUI_NORMAL)
cv2.imshow('Region of Interest', roi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
roi.shape
# Out:
# (550, 500, 3)

# %% [markdown]
# ### Resizing the Image

# %%
resized_image = cv2.resize(image, (534,800))
cv2.namedWindow('Resized Image', cv2.WINDOW_NORMAL)
cv2.imshow('Resized Image',resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [raw]
#     ==>> The problem with this approach is that the aspect ratio of the image is not maintained. So we need to do some extra work in order to maintain a proper aspect ratio..,

# %%
H/W
# Out:
# 0.6679166666666667

# %%
ratio = 800 / W
print(ratio)

dim=(800, int(H * ratio))
print('WIdth: {}, Height: {}'.format(dim[0],dim[1]))


#in resize resize(image,(width,height))

resized_image = cv2.resize(image, dim)

cv2.namedWindow('Resized Image', cv2.WINDOW_AUTOSIZE)
cv2.imshow('Resized Image', resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0.3333333333333333
# WIdth: 800, Height: 534

# %% [raw]
# Rotating Image

# %%
# Calculating the center of the image.,
center = w,h = (W//2,H//2)
print(center)

# Generating a rotation matrix.,
matrix = cv2.getRotationMatrix2D(center, -45, 1)
print(matrix)

# Performing the affine transformation.,
rotate = cv2.warpAffine(image, matrix, (W, H))
#print(rotate)

cv2.namedWindow('Rotation Image', cv2.WINDOW_NORMAL)
cv2.imshow('Rotation Image', rotate)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (1200, 801)
# [[ 7.07106781e-01 -7.07106781e-01  9.17864394e+02]
#  [ 7.07106781e-01  7.07106781e-01 -6.13920669e+02]]

# %% [raw]
# drawing a rectangle

# %% [raw]
# It takes in 5 arguments –
#
#     Image
#     Top-left corner co-ordinates
#     Bottom-right corner co-ordinates
#     Color (in BGR format)
#     Line width

# %%
# We are copying the original image, as it is an in-place operation..,
output = image.copy()

                  #500 to 50 width 1500 to 900 height
        # (w1,h1), (w2,h2)
rectangle = cv2.rectangle(output, (500,1500), (50, 900), (255, 0, 0), 5)
print(type(rectangle))

# Using the rectangle() function to create a rectangle..,
cv2.namedWindow('Rectangle', cv2.WINDOW_NORMAL)
cv2.imshow('Rectangle', rectangle)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>

# %%
image.shape
# Out:
# (1603, 2400, 3)

# %%
# We are copying the original image, as it is an in-place operation..,
output = image.copy()

          #500 to 1000 width 1000 to 1500 height
#           cv2.rectangle( image ,    (w1,h1),   (w2,h2),       b,g,r),  line width
rectangle = cv2.rectangle(output, (500, 1000), (1000, 1500), (0, 0, 250), 5)
print(type(rectangle))

# Using the rectangle() function to create a rectangle..,
cv2.namedWindow('Rectangle', cv2.WINDOW_NORMAL)
cv2.imshow('Rectangle', rectangle)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>

# %% [raw]
# display text

# %% [raw]
# It takes in 7 arguments –
#
#     Image
#     Text to be displayed
#     Bottom-left corner co-ordinates, from where the text should start
#     Font
#     Font size
#     Color (BGR format)
#     Line width

# %%
output =image.copy()

  #  putText(  image  ,    text  ,     bottom left corner (w2,h2) ,font , font size, font color, line width )
text = cv2.putText(output, 'Hello Elliot', (900, 750), cv2.FONT_HERSHEY_SIMPLEX, 4, (255, 500, 0), 5)
#print(text)

cv2.namedWindow('Display Text Image', cv2.WINDOW_NORMAL)
cv2.imshow('Display Text Image', text)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [raw]
# creating image of matrix

# %%
mat=np.random.randint(0,256,(1000,100,3))
mat.shape
# Out:
# (1000, 100, 3)

# %%
from PIL import Image

img = Image.fromarray(mat,'RGB')
img.save('BW.png')
img.show()

# %% [raw]
# ## i) Read an Image :-
# ## cv2.imread(Path, Flag)
#     ### Parameters :-
#     ==>> Path - The image should be in the working directory or a full path of image should be given..,
#     ==>> Flag - It specifies the way in which image should be read, default value is cv2.IMREAD_COLOR..,
#             => cv2.IMREAD_COLOR     - Loads a color image. Any transparency of image will be neglected..,
#                                       Alternatively, we can pass integer value 1 for this flag..,
#             => cv2.IMREAD_GRAYSCALE - Loads image in grayscale mode..,
#                                       Alternatively, we can pass integer value 0 for this flag..,
#             => cv2.IMREAD_UNCHANGED - Loads image as such including alpha channel..,
#                                       Alternatively, we can pass integer value -1 for this flag..,

# %% [raw]
# ## ii) Display an Image :-
# ## cv2.imshow(window_name, image)
#     ### Parameters :-
#     ==>> window_name - A string representing the name of the window in which image to be displayed..,
#                        We can create as many windows, but with different window names..,
#     ==>> image       - The image that is to be displayed..,
#     ==>> Return Value - It doesn’t returns anything..,

# %% [raw]
# ### cv2.waitKey() :
#     => It's a keyboard binding function. Its argument is the time in milliseconds..,
#     => The function waits for specified milliseconds for any keyboard event. If you press any key in that
#        time, the program continues.
#     => If 0 is passed, it waits indefinitely for a key stroke..,
# ### cv2.destroyAllWindows() :
#     => It simply destroys all the windows we created. If you want to destroy any specific window, use the
#        function cv2.destroyWindow() where you pass the exact window name as the argument..,

# %%
# Loads a color image as it is..,
image_01 = cv2.imread('TengaVally.jpeg', 1)

cv2.namedWindow('TengaVally Image', cv2.WINDOW_KEEPRATIO)
cv2.imshow('TengaVally Image', image_01)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Loads image in grtyscale mode..,
image_02 = cv2.imread('TengaVally.jpeg', 0)

cv2.namedWindow('TengaVally Image', cv2.WINDOW_KEEPRATIO)
cv2.imshow('TengaVally Image', image_02)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Loads image as such including alpha channel..,
image_03 = cv2.imread('TengaVally.jpeg', -1)

cv2.namedWindow('TengaVally Image', cv2.WINDOW_KEEPRATIO)
cv2.imshow('TengaVally Image', image_03)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # iii) Write an Image :
# ## cv2.imwrite(filename, image)
# cv2.imwrite() method is used to save an image to any storage device. This will save the image according to the specified format in current working directory.
#
# Syntax: cv2.imwrite(filename, image)
#
# Parameters:
# filename: A string representing the file name. The filename must include image format like .jpg, .png, etc.
# image: It is the image that is to be saved.
#
# Return Value: It returns true if image is saved successfully.

# %%
cv2.imwrite('roag1.jpg',image)
# Out:
# True

# %%
cv2.imwrite('NewImage.jpeg', image_01)
# Out:
# True

# %%
i2=cv2.imread('bike.jpg',cv2.IMREAD_COLOR)
cv2.namedWindow('Bike',cv2.WINDOW_NORMAL)
cv2.imshow('Bike',i2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# %%
image_02 = cv2.imread('Raigad.jpeg', 0)

cv2.namedWindow('OP2', cv2.WINDOW_NORMAL)
cv2.imshow('OP2', image_02)

K = cv2.waitKey(0) & 0xFF
print(K)
if K == 27:          #(27 for ESC, 32 for SPACE,  # Wait for ESC key to exit
    print(K)
    cv2.destroyAllWindows()
elif K == ord('s'):    # Wait for 's' key to save and exit
    print(K)
    cv2.imwrite('Raigad_Grayscale.png', image_02)
    cv2.destroyAllWindows()
# Out:
# 13

# %%
cv2.waitKey(0) & 255
# Out:
# 13

# %%
ord('s'),ord('a')
# Out:
# (115, 97)

# %%
ord('2'),ord('1')
# Out:
# (50, 49)

# %% [raw]
#     ==>> The ord() function returns the number representing the unicode (ASCII) code of a specified character..,

# %% [markdown]
# ## Using Matplotlib :
#     ==>> A plotting library for Python which gives us a wide variety of plotting methods..,

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('ManasNatPark.jpeg', 1)

### For BGR to RGB in case of COLORed images..,

b, g, r = cv2.split(image)   
image = cv2.merge([r, g, b])

img2 = image[:,:,::-1]
plt.imshow(image, cmap = 'gray')

# %% [raw]
# ### BGR to RGB :-
#      ==>> Color image loaded by OpenCV is in BGR mode. But Matplotlib displays in RGB mode. So color images
#          will not be displayed correctly in Matplotlib if image is read with OpenCV..,
#     ==>> Sp to avoid this we need to convert BGR image (OpenCV) to RGB (MatPlotLib) using below functions :
#
#     #b, g, r = cv2.split(image)
#     #image = cv2.merge([r,g,b])
#
#         ### OR ###
#
#     #img2 = image[:,:,::-1]
#
#     => Kindly note that this will work only for COLORed image reading..,

# %%
plt.imshow(image)

# %%
plt.imshow(image, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])     # to hide tick values on X and Y axis empty list is given
plt.show()

# %%
from matplotlib import image as img
image = img.imread('ManasNatPark.jpeg', 1)
plt.imshow(image, cmap = 'gray')

# %% [markdown]
# ## Color Spaces in OpenCV | Python
#     ==>> Color spaces are a way to represent the color channels present in the image that gives the image that particular hue. There are several different color spaces and each has its own significance..,
# ### i) BGR Color Space : (Blue, Green, Red)
#     ==>> OpenCV’s default color space is RGB. However, it actually stores color in the BGR format.
#          It is an additive color model where the different intensities of Blue, Green and Red give different
#          shades of color..,
# ### ii) HSV Color Space : (Hue, Saturation, Value)
#     ==>> It stores color information in a cylindrical representation of RGB color points. It attempts to depict the colors as perceived by the human eye.
#     ==>> Hue value varies from 0-179.,
#     ==>> Saturation value varies from 0-255.,
#     ==>> Value value varies from 0-255.,
#     ==>> It is mostly used for color segmentation purpose..,
# ### iii) CMYK Color Space : (Cyan, Magenta, Yellow, Black)
#     ==>> Unlike, RGB it is a subtractive color space. The CMYK model works by partially or entirely masking
#          colors on a lighter, usually white, background. The ink reduces the light that would otherwise be
#          reflected. Such a model is called subtractive because inks “subtract” the colors red, green and blue
#          from white light. White light minus red leaves cyan, white light minus green leaves magenta, and
#          white light minus blue leaves yellow..,

# %%
image_01 = cv2.imread('TengaVally.jpeg', 1)
B, G, R = cv2.split(image_01)
B.shape

# %%
G.shape

# %%
R.shape

# %%
zeros.shape

# %%
image_01.shape

# %%
#loads color as it is 
image_01 = cv2.imread('TengaVally.jpeg', 1)
B, G, R = cv2.split(image_01)

#creting matrix of all zeroes of size B, G, R for merging wth individual colors
zeros = np.zeros(B.shape, np.uint8)
B = cv2.merge((B, zeros, zeros))
B.shape

# %%
#to convert float to int 
np.uint16(5.6)

# %%
#loads color as it is 
image_01 = cv2.imread('TengaVally.jpeg', 1)
B, G, R = cv2.split(image_01)

#creting matrix of all zeroes of size B, G, R for merging wth individual colors
zeros = np.zeros(B.shape, np.uint8)

#creating B, G, R as individual channel with making other channels to zero
B = cv2.merge((B, zeros, zeros))
G = cv2.merge((zeros, G, zeros))
R = cv2.merge((zeros, zeros, R))

#display original image
cv2.namedWindow('Original', cv2.WINDOW_NORMAL)
cv2.imshow('Original', image_01)
#cv2.waitKey(0)

cv2.namedWindow('Blue', cv2.WINDOW_NORMAL)
cv2.imshow('Blue', B)
#cv2.waitKey(0)

cv2.namedWindow('Green', cv2.WINDOW_NORMAL)
cv2.imshow('Green', G)
#cv2.waitKey(0)

cv2.namedWindow('Red', cv2.WINDOW_NORMAL)
cv2.imshow('Red', R)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### B) Getting Started with Videos :-
# ## ToDo :-
#     ==>> i)   To read video, display video and save video..,
#          ii)  To capture from Camera and display it..,
#          iii) cv2.VideoCapture(), cv2.VideoWriter()..,

# %%
import numpy as np
import pandas as pd 
import cv2
import matplotlib.pyplot as plt

# %% [raw]
# cv2.VideoCapture(0): Means first camera or webcam.
# cv2.VideoCapture(1):  Means second camera or webcam.
# cv2.VideoCapture("file name.mp4"): Means video file

# %%
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Display the resulting frame
    cv2.imshow('frame', gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
gray
# Out:
# array([[ 59,  60,  57, ..., 126, 129, 127],
#        [ 58,  58,  57, ..., 120, 124, 129],
#        [ 64,  61,  63, ..., 122, 127, 137],
#        ...,
#        [ 60,  60,  63, ..., 121, 136, 152],
#        [ 63,  62,  65, ..., 106, 126, 139],
#        [ 69,  66,  68, ..., 101, 122, 130]], dtype=uint8)

# %%
cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640,480))

while cap.isOpened():
    ret, frame = cap.read()
    if ret == True:
        frame = cv2.flip(frame, 0)
    
        #write the flipped frame
        out.write(frame)

        cv2.imshow('frame', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
        
# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaych\\Downloads\\iAnalyst\\Opencv'

# %%
cap = cv2.VideoCapture("FlixTor _ Watch Better Call Saul (2015) Online Free on flixtor.one - Google Chrome 2021-01-23 14-08-46.mp4")


# Read until video is completed
while cap.isOpened():
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        
           # Display the resulting frame
        cv2.imshow('Frame', frame)
        
         # Press Q on keyboard to  exit
        if cv2.waitKey(15) & 0xFF == ord('q'):  #== 27: (Esc)
            break
      # Break the loop
    else:
        break
        
# When everything done, release 
# the video capture object        
cap.release()
   
# Closes all the frames
cv2.destroyAllWindows()

# %% [markdown]
# ### C) Drawing Functions in OpenCV :-
# ## ToDo :-
#     ==>> i)  To draw different geometric shapes with OpenCV.,
#          ii) Functions : cv2.line(), cv2.circle() , cv2.rectangle(), cv2.ellipse(), cv2.putText() etc.,
# ## Code (Common Arguments) :-
#     ==>> img         - Image where we wants to draw shapes.,
#     ==>> start_point - It is the starting coordinates of The SHAPE. The coordinates are represented as tuples
#                        of two values i.e. (X coordinate value, Y coordinate value)..,
#          end_point   - It is the ending coordinates of The SHAPE. The coordinates are represented as tuples of
#                        two values i.e. (X coordinate value, Y coordinate value).
#          color       - Color of the shape..,
#                      > For BGR, pass it as a tuple, eg: (255,0,0) for blue.,
#                      > For grayscale, just pass the scalar value.,
#          thickness   - Thickness of the shape., Default thickness = 1.
#                        If -1 is passed for closed figures like circles, it will fill the shape.,
#          lineType    - Type of line, whether 8-connected, anti-aliased line etc. By default - 8-connected.,
#                      > cv2.LINE_AA gives anti-aliased line which looks great for curves..,

# %% [markdown]
# ## i) Drawing Line :-
# ## cv2.line(image, start_point, end_point, color, thickness)###

# %%
### Create a black image and draw a blue line on it from top-left to bottom-right corners..

#create blank image

image = np.zeros((512,512,3), np.uint8)
#print(image)

# Draw a diagonal blue line with thickness of 5 px.,

        ## cv2.line(image, start_point, end_point, color, thickness)
mod_image = cv2.line(image, (0, 0), (400, 200), (0, 52, 250), 3)
#mod_image

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# #### ii) Drawing Rectangle :-
# ## cv2.rectangle(image, start_point, end_point, color, thickness)

# %%
# Create blank image.,
image = np.zeros((512, 512, 3), np.uint8)

# draw a green rectangle at the top-right corner of image..,

         ## cv2.rectangle(image, start_point, end_point, color, thickness)
mod_image = cv2.rectangle(image, (150, 200), (350, 400), (250, 0 , 250), 10)

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### iii) Drawing Circle :-
# ## cv2.circle(image, center_coordinates, radius, color, thickness)
#     ==>> center_coordinates - It is the center coordinates of circle. The coordinates are represented as
#                               tuples of two values i.e. (X coordinate value, Y coordinate value)..,
#          radius             - The Radius of the circle.,

# %%
# Create blank image.,
image = np.zeros((512, 512, 3), np.uint8)

# draw a circle inside the rectangle drawn above.,
mod_image = cv2.circle(mod_image, (250, 300), 60, (250 , 250, 25), -1 )

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %%
# Create blank image.,
image = np.zeros((512, 512, 3), np.uint8)

# draw a circle inside the rectangle drawn above.,
mod_image = cv2.circle(mod_image, (250, 300), 50, (0 , 250, 255), -1 )

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### iv) Drawing Ellipse :-
# ## cv2.ellipse(image, centerCoordinates, axesLength, angle, startAngle, endAngle, color [, thickness[, lineType[, shift]]])
#
#     => centerCoordinates - It is the center coordinates of ellipse. The coordinates are represented as tuples
#                            of two values i.e. (X coordinate value, Y coordinate value).,
#        axesLength        - It contains tuple of two variables containing major and minor axis of ellipse
#                            (major axis length, minor axis length).,
#        angle             - Ellipse rotation angle in degrees.,
#        startAngle        - Starting angle of the elliptic arc in degrees.,
#        endAngle          - Ending angle of the elliptic arc in degrees.,
#        lineType          - This is an optional parameter. It gives the type of the ellipse boundary.,
#        shift             - This is an optional parameter. It denotes the number of fractional bits in the
#                            coordinates of the center and values of axes.,

# %%
image = np.zeros((512, 512, 3), np.uint8)

#draw half ellipse at center of image
mod_image = cv2.ellipse(image, (250, 250), (200, 100), -90, 360, 0, (0, 255, 0), 5)

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %%
idx = np.where(mod_image == 0)
idx
# Out:
# (array([  0,   0,   0, ..., 511, 511, 511], dtype=int64),
#  array([  0,   0,   0, ..., 511, 511, 511], dtype=int64),
#  array([0, 1, 2, ..., 0, 1, 2], dtype=int64))

# %%
mod_image[idx] = 150
plt.imshow(mod_image)

# %% [markdown]
# ## v) Drawing Arrowed Line :
# ## cv2.arrowedLine(image, start_point, end_point, color[, thickness[, line_type[, shift[, tipLength]]]])###

# %%
# Create blank image.,
image = np.zeros((512, 512, 3), np.uint8)

mod_image = cv2.arrowedLine(image, (50, 50), (200,300), (0, 255, 0), 5)

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %%
image = np.zeros((512, 512, 3), np.uint8)

mod_image = cv2.arrowedLine(image, (50, 450), (450, 50), (0, 255, 0), 5)

B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### vi) Adding Text to Images :
# ## cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
#     => text - Text string to be drawn.,
#        org  - It is the coordinates of the bottom-left corner of the text string in the image. The coordinates
#               are represented as tuples of two values i.e. (X coordinate value, Y coordinate value).,
#        font - It denotes the font type. Some of font types are FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN etc.,
#        fontScale - Font scale factor that is multiplied by the font-specific base size.,

# %%
# Out:
# (50, 250)

# %%
image = np.ones((512,512,3), np.uint8)*255

#font 
font = cv2.FONT_HERSHEY_SIMPLEX

#org
org = (50,250)

#fontscale
fontscale = 1

#Blue color in BGR
color = (2, 0, 100)

#line thickness of 2 px
thickness = 1

mod_image = cv2.putText(image, 'J@YCHYAUMYAU', org, font, fontscale, color, thickness, cv2.LINE_AA)

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %%
image = np.zeros((512,512,3), np.uint8)

#font 
font = cv2.FONT_HERSHEY_SIMPLEX

#org
org = (50,250)

#fontscale
fontscale = 1

#Blue color in BGR
color = (255, 0, 0)

#line thickness of 2 px
thickness = 2

mod_image = cv2.putText(image, 'J@YCHYAUMYAU', org, font, fontscale, color, thickness, cv2.LINE_AA)

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### Ex. Draw a triangle with centroid using OpenCV:-

# %% [markdown]
# ### ==>> Given 3 Vertices of Triangle..,
#     P1 = (100, 400), P2 = (300, 100), P3 = (400, 100)
#
# ==>> Approach :-
#     => Create a black window with three color channels with resolution 500 x 500..,
#     => Draw three lines passing through the given points using the inbuilt line function of OpenCV..,
#     => It will create a triangle on the black window., Now find centroid of the triangle :
#
#     (X, Y) = {((x1+x2+x3)/3), ((y1+y2+y3)/3)}
#
#     => We can draw this centroid on the black window using circle function of OpenCV with zero thickness..,

# %%
#width and height of black window
width = 500
height = 500

#create black window
image = np.zeros((height, width, 3), np.uint8)

#three vertices of triangle
P1 = (200, 100)
P2 = (100, 100)
P3 = (250, 400)

#drawing three lines with three vertices to form triangle
cv2.line(image, P1, P2, (255, 0, 0), 3)
cv2.line(image, P2, P3, (0, 255, 0), 3)
cv2.line(image, P3, P1, (0, 0, 255), 3)

#finding centroid of triangle
Centroid = (int((P1[0] + P2[0] + P3[0])/3), int((P1[1] + P2[1] + P3[1])/3))
print('Coordinates of Centroid: ',Centroid)

#draw centroid
cv2.circle(image, Centroid, 3, (255, 255, 255), 7)

B, G, R = cv2.split(image)
image = cv2.merge([R, G, B])
plt.imshow(image)
# Out:
# Coordinates of Centroid:  (183, 200)

# %%
int((P1[1] + P2[1] + P3[1])/3)
# Out:
# 200

# %% [markdown]
# ## Core Operations :
# # A) Arithmetic Operations : (Addition and Subtraction)
# ## i) Addition of Images :-
# ## cv2.add(img1, img2)
#     ==>> We can add two images by using function cv2.add(). This directly adds up image pixels in the two
#          images..,
#     ==>> But adding the pixels is not an ideal situation. So, we use cv2.addweighted()..,
#          Remember, both images should be of equal size and depth..,
# ## cv2.addWeighted(img1, wt1, img2, wt2, gammaValue)
#     => img1       - First Input Image array(Single-channel, 8-bit or floating-point)..,
#     => wt1        - Weight of the first input image elements to be applied to the final image..,
#     => img2       - Second Input Image array(Single-channel, 8-bit or floating-point)..,
#     => wt2        - Weight of the second input image elements to be applied to the final image..,
#     => gammaValue - Measurement of light..,

# %%
### Addition of Two Images..,

import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image_01 = cv2.imread('ManasNatPark.jpeg')
image_02 = cv2.imread('Mo.jpg')
print(image_01.shape, '|'*5, image_02.shape)
# Out:
# (2179, 3874, 3) ||||| (2153, 2237, 3)

# %%
image_01 = cv2.resize(image_01, (1920, 1080))

# %%
image_01.shape
# Out:
# (1080, 1920, 3)

# %%
image_02 = cv2.resize(image_02, (1920, 1080))
image_02.shape
# Out:
# (1080, 1920, 3)

# %%
# cv2.addWeighted is applied over the image inputs with applied parameters.,
WeightedSum_Image = cv2.addWeighted(image_01, 0.5, image_02, 0.5, 0)

#Display Images with Normal Window OpenCV
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

cv2.namedWindow('WeightedSum_Image', cv2.WINDOW_NORMAL)
cv2.imshow('WeightedSum_Image', WeightedSum_Image)

cv2.waitKey(0)
cv2.destroyAllWindows()

#convert BGR to RGB
B, G, R = cv2.split(WeightedSum_Image)
WeightedSum_Image = cv2.merge([R, G, B])
plt.imshow(WeightedSum_Image)

# %% [markdown]
# ## ii) Subtraction of Images :
# ## cv2.subtract(src1, src2)
#     ==>> Just like addition, we can subtract the pixel values in two images and merge them with the help of
#          cv2.subtract(). The images should be of equal size and depth..,

# %%
image_01 = cv2.imread('Image_03.jpg')
image_02 = cv2.imread('Image_04.jpg')
print(image_01.shape, '|'*5, image_02.shape)
# Out:
# (168, 300, 3) ||||| (168, 300, 3)

# %%
##subtraction of two images

Subtracted_Image = cv2.subtract(image_01, image_02)

#Display Images with Normal Window OpenCV
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.namedWindow('Subtracted_Image', cv2.WINDOW_NORMAL)
cv2.imshow('Subtracted_Image', Subtracted_Image)

cv2.waitKey(0)
cv2.destroyAllWindows()

#convert BGR to RGB
B, G, R = cv2.split(Subtracted_Image)
Subtracted_Image = cv2.merge([R, G, B])
plt.imshow(Subtracted_Image)

# %% [markdown]
# ### B) Bitwise Operations on Binary Images :
# ## i) Bitwise AND operation on Image :-
# ### cv2.bitwise_and(source1, source2, destination, mask)
#     ==>> source1 - First Input Image array(Single-channel, 8-bit or floating-point).,
#          source2 - Second Input Image array(Single-channel, 8-bit or floating-point).,
#          dest    - Output array (Similar to the dimensions and type of Input image array).,
#          mask    - Operation mask, Input / output 8-bit single-channel mask.,

# %% [raw]
# part of image containing information in both are showed
# Here image containing black part are taken

# %%
image_01 = cv2.imread('Image_01.png')
image_02 = cv2.imread('Image_02.png')
print(image_01.shape, '|'*5, image_02.shape)
# Out:
# (250, 499, 3) ||||| (250, 499, 3)

# %%
#apply bitwise AND operation on images
mod_image = cv2.bitwise_and(image_01, image_02, mask = None)

# Display Images with Normal Window OpenCV..,
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)
cv2.namedWindow('Bitwise AND_Image', cv2.WINDOW_NORMAL)
cv2.imshow('Bitwise AND_Image', mod_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(image_01)
image_01 = cv2.merge([R, G, B])
plt.imshow(image_01)

# %%
B, G, R = cv2.split(image_02)
image_02 = cv2.merge([R, G, B])
plt.imshow(image_02)

# %%
# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### ## ii) Bitwise OR operation on Image :-
# ### cv2.bitwise_or(source1, source2, destination, mask)

# %% [raw]
# image part containing information on both are ignored
# Here image containing white part are taken
# opposite of AND

# %%
### Bitwise OR Operation..,

import cv2
import numpy as np

# images are loaded with imread command.,
image_01 = cv2.imread('Image_01.png')
image_02 = cv2.imread('Image_02.png')

# Apply Bitwise OR operation on images..,
mod_image = cv2.bitwise_or(image_01, image_02, mask = None)

# Display Images with Normal Window OpenCV..,
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)
cv2.namedWindow('Bitwise OR_Image', cv2.WINDOW_NORMAL)
cv2.imshow('Bitwise OR_Image', mod_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### iii) Bitwise XOR operation on Image :-
# ### cv2.bitwise_xor(source1, source2, destination, mask)

# %%
### Bitwise XOR Operation..,

import cv2
import numpy as np

# images are loaded with imread command.,
image_01 = cv2.imread('Image_01.png')
image_02 = cv2.imread('Image_02.png')

# Apply Bitwise XOR operation on images..,
mod_image = cv2.bitwise_xor(image_01, image_02, mask = None)

# Display Images with Normal Window OpenCV..,
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)
cv2.namedWindow('Bitwise XOR_Image', cv2.WINDOW_NORMAL)
cv2.imshow('Bitwise XOR_Image', mod_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image)
mod_image = cv2.merge([R, G, B])
plt.imshow(mod_image)

# %% [markdown]
# ### iv) Bitwise NOT operation on Image :-
# ### cv2.bitwise_not(source1, destination, mask)

# %%
# images are loaded with imread command.,
image_01 = cv2.imread('Image_01.png')
image_02 = cv2.imread('Image_02.png')

# Apply Bitwise NOT operation on images..,
mod_image01 = cv2.bitwise_not(image_01, mask = None)
mod_image02 = cv2.bitwise_not(image_02, mask = None)

# Display Images with Normal Window OpenCV..,
cv2.namedWindow('Image_01', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01', image_01)
cv2.namedWindow('Image_02', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02', image_02)

cv2.namedWindow('Image_01_NOT', cv2.WINDOW_NORMAL)
cv2.imshow('Image_01_NOT', mod_image01)
cv2.namedWindow('Image_02_NOT', cv2.WINDOW_NORMAL)
cv2.imshow('Image_02_NOT', mod_image02)

cv2.waitKey(0)
cv2.destroyAllWindows()

# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image01)
mod_image01 = cv2.merge([R, G, B])
plt.imshow(mod_image01)

# %%
# Convert BGR (OpenCV) to RGB (MatPlotLib).,
B, G, R = cv2.split(mod_image02)
mod_image02 = cv2.merge([R, G, B])
plt.imshow(mod_image02)
